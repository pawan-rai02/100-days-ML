# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
x, y = make_classification(n_samples=10000, n_features=10, n_informative=3, random_state=42)

# %%
x
# Out:
# array([[ 0.44190545,  0.40400779, -1.86214076, ...,  0.2620047 ,
#         -0.12555752, -0.24706556],
#        [ 0.65003833, -0.28793496, -1.02038245, ..., -0.03184673,
#         -0.25274359, -1.80697276],
#        [ 0.43682472, -0.61849569,  1.03789091, ...,  1.02845222,
#          0.75423528, -1.33013702],
#        ...,
#        [ 0.43437047,  0.94088788,  0.21176426, ..., -0.89398799,
#         -0.27603158,  0.12700477],
#        [-0.2379782 , -1.26323076, -0.88734633, ...,  0.24538081,
#          0.08311803, -0.99548218],
#        [-1.78080822, -1.71161486,  1.74962866, ..., -0.1790199 ,
#         -0.52330349, -1.91299898]], shape=(10000, 10))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 0.9265

# %% [markdown]
# # Bagging

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(random_state=42),
    n_estimators=500,
    max_samples=0.25,
    random_state=42,
    bootstrap=True
)
bag.fit(x_train, y_train)
y_pred_bag = bag.predict(x_test)
print("Bagging Accuracy:", accuracy_score(y_test, y_pred_bag))
bag.fit(x_train, y_train)
y_pred_bag = bag.predict(x_test)
print("Bagging Accuracy:", accuracy_score(y_test, y_pred_bag))
# Out:
# Bagging Accuracy: 0.945
# Bagging Accuracy: 0.945
